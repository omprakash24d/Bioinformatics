# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot([12,13,14],[1,2,3])
plt.title("Om Prakash")
plt.xlabel("Name")
plt.ylabel("Age")
plt.colour('r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 7
#       5 plt.xlabel("Name")
#       6 plt.ylabel("Age")
# ----> 7 plt.colour('red')
#       8 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'colour'
